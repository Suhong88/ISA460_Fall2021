# %% [markdown]
# ##Chicago Crime Data Analysis
# This project is based on Chicago crime data downloaded from [Chicago Data Portal](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2). The data set include the crime in Chicago from 2001 to present

# %%
# %fs ls /mnt/isa460/data/chicago_crime
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/isa460/data/chicago_crime/Crimes2001_2021.csv</td><td>Crimes2001_2021.csv</td><td>1952853549</td></tr><tr><td>dbfs:/mnt/isa460/data/chicago_crime/parquet/</td><td>parquet/</td><td>0</td></tr><tr><td>dbfs:/mnt/isa460/data/chicago_crime/policestation.csv</td><td>policestation.csv</td><td>5723</td></tr></tbody></table></div>

# %%
# import csv data from S3 storage folder

df=spark.read.csv("/mnt/isa460/data/chicago_crime/Crimes2001_2021.csv", header=True, inferSchema=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- ID: integer (nullable = true)
# -- Case Number: string (nullable = true)
# -- Date: string (nullable = true)
# -- Block: string (nullable = true)
# -- IUCR: string (nullable = true)
# -- Primary Type: string (nullable = true)
# -- Description: string (nullable = true)
# -- Location Description: string (nullable = true)
# -- Arrest: boolean (nullable = true)
# -- Domestic: boolean (nullable = true)
# -- Beat: integer (nullable = true)
# -- District: integer (nullable = true)
# -- Ward: integer (nullable = true)
# -- Community Area: integer (nullable = true)
# -- FBI Code: string (nullable = true)
# -- X Coordinate: integer (nullable = true)
# -- Y Coordinate: integer (nullable = true)
# -- Year: integer (nullable = true)
# -- Updated On: string (nullable = true)
# -- Latitude: double (nullable = true)
# -- Longitude: double (nullable = true)
# -- Location: string (nullable = true)
# -- Historical Wards 2003-2015: integer (nullable = true)
# -- Zip Codes: integer (nullable = true)
# -- Community Areas: integer (nullable = true)
# -- Census Tracts: integer (nullable = true)
# -- Wards: integer (nullable = true)
# -- Boundaries - ZIP Codes: integer (nullable = true)
# -- Police Districts: integer (nullable = true)
# -- Police Beats: integer (nullable = true)
#
# </div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Case Number</th><th>Date</th><th>Block</th><th>IUCR</th><th>Primary Type</th><th>Description</th><th>Location Description</th><th>Arrest</th><th>Domestic</th><th>Beat</th><th>District</th><th>Ward</th><th>Community Area</th><th>FBI Code</th><th>X Coordinate</th><th>Y Coordinate</th><th>Year</th><th>Updated On</th><th>Latitude</th><th>Longitude</th><th>Location</th><th>Historical Wards 2003-2015</th><th>Zip Codes</th><th>Community Areas</th><th>Census Tracts</th><th>Wards</th><th>Boundaries - ZIP Codes</th><th>Police Districts</th><th>Police Beats</th></tr></thead><tbody><tr><td>10224738</td><td>HY411648</td><td>09/05/2015 01:30:00 PM</td><td>043XX S WOOD ST</td><td>0486</td><td>BATTERY</td><td>DOMESTIC BATTERY SIMPLE</td><td>RESIDENCE</td><td>false</td><td>true</td><td>924</td><td>9</td><td>12</td><td>61</td><td>08B</td><td>1165074</td><td>1875917</td><td>2015</td><td>02/10/2018 03:50:01 PM</td><td>41.815117282</td><td>-87.669999562</td><td>(41.815117282, -87.669999562)</td><td>29</td><td>14924</td><td>59</td><td>706</td><td>3</td><td>37</td><td>23</td><td>108</td></tr><tr><td>10224739</td><td>HY411615</td><td>09/04/2015 11:30:00 AM</td><td>008XX N CENTRAL AVE</td><td>0870</td><td>THEFT</td><td>POCKET-PICKING</td><td>CTA BUS</td><td>false</td><td>false</td><td>1511</td><td>15</td><td>29</td><td>25</td><td>06</td><td>1138875</td><td>1904869</td><td>2015</td><td>02/10/2018 03:50:01 PM</td><td>41.895080471</td><td>-87.765400451</td><td>(41.895080471, -87.765400451)</td><td>4</td><td>4299</td><td>26</td><td>562</td><td>45</td><td>5</td><td>25</td><td>67</td></tr><tr><td>11646166</td><td>JC213529</td><td>09/01/2018 12:01:00 AM</td><td>082XX S INGLESIDE AVE</td><td>0810</td><td>THEFT</td><td>OVER $500</td><td>RESIDENCE</td><td>false</td><td>true</td><td>631</td><td>6</td><td>8</td><td>44</td><td>06</td><td>null</td><td>null</td><td>2018</td><td>04/06/2019 04:04:43 PM</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>10224740</td><td>HY411595</td><td>09/05/2015 12:45:00 PM</td><td>035XX W BARRY AVE</td><td>2023</td><td>NARCOTICS</td><td>POSS: HEROIN(BRN/TAN)</td><td>SIDEWALK</td><td>true</td><td>false</td><td>1412</td><td>14</td><td>35</td><td>21</td><td>18</td><td>1152037</td><td>1920384</td><td>2015</td><td>02/10/2018 03:50:01 PM</td><td>41.937405765</td><td>-87.716649687</td><td>(41.937405765, -87.716649687)</td><td>15</td><td>21538</td><td>22</td><td>216</td><td>12</td><td>39</td><td>7</td><td>168</td></tr><tr><td>10224741</td><td>HY411610</td><td>09/05/2015 01:00:00 PM</td><td>0000X N LARAMIE AVE</td><td>0560</td><td>ASSAULT</td><td>SIMPLE</td><td>APARTMENT</td><td>false</td><td>true</td><td>1522</td><td>15</td><td>28</td><td>25</td><td>08A</td><td>1141706</td><td>1900086</td><td>2015</td><td>02/10/2018 03:50:01 PM</td><td>41.881903443</td><td>-87.755121152</td><td>(41.881903443, -87.755121152)</td><td>11</td><td>22216</td><td>26</td><td>696</td><td>23</td><td>32</td><td>25</td><td>81</td></tr><tr><td>10224742</td><td>HY411435</td><td>09/05/2015 10:55:00 AM</td><td>082XX S LOOMIS BLVD</td><td>0610</td><td>BURGLARY</td><td>FORCIBLE ENTRY</td><td>RESIDENCE</td><td>false</td><td>false</td><td>614</td><td>6</td><td>21</td><td>71</td><td>05</td><td>1168430</td><td>1850165</td><td>2015</td><td>02/10/2018 03:50:01 PM</td><td>41.744378879</td><td>-87.658430635</td><td>(41.744378879, -87.658430635)</td><td>18</td><td>21554</td><td>70</td><td>575</td><td>13</td><td>59</td><td>20</td><td>237</td></tr><tr><td>10224743</td><td>HY411629</td><td>09/04/2015 06:00:00 PM</td><td>021XX W CHURCHILL ST</td><td>0620</td><td>BURGLARY</td><td>UNLAWFUL ENTRY</td><td>RESIDENCE-GARAGE</td><td>false</td><td>false</td><td>1434</td><td>14</td><td>32</td><td>24</td><td>05</td><td>1161628</td><td>1912157</td><td>2015</td><td ...

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: 7415327</div>

# %% [markdown]
# ##ETL
#
# ### Replace space in column names as _, change the names to all lower cases letters.

# %%
from pyspark.sql.functions import *

columns=df.columns

for col in columns:
  new_col=col.replace(" ", "_").lower()
  df=df.withColumnRenamed(col, new_col)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###Change date from string type to timestamp type

# %%
from pyspark.sql.functions import to_timestamp
help(to_timestamp)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on function to_timestamp in module pyspark.sql.functions:
#
# to_timestamp(col, format=None)
#     Converts a :class:`~pyspark.sql.Column` into :class:`pyspark.sql.types.TimestampType`
#     using the optionally specified format. Specify formats according to `datetime pattern`_.
#     By default, it follows casting rules to :class:`pyspark.sql.types.TimestampType` if the format
#     is omitted. Equivalent to ``col.cast(&#34;timestamp&#34;)``.
#
#     .. _datetime pattern: https://spark.apache.org/docs/latest/sql-ref-datetime-pattern.html
#
#     .. versionadded:: 2.2.0
#
#     Examples
#     --------
#     &gt;&gt;&gt; df = spark.createDataFrame([(&#39;1997-02-28 10:30:00&#39;,)], [&#39;t&#39;])
#     &gt;&gt;&gt; df.select(to_timestamp(df.t).alias(&#39;dt&#39;)).collect()
#     [Row(dt=datetime.datetime(1997, 2, 28, 10, 30))]
#
#     &gt;&gt;&gt; df = spark.createDataFrame([(&#39;1997-02-28 10:30:00&#39;,)], [&#39;t&#39;])
#     &gt;&gt;&gt; df.select(to_timestamp(df.t, &#39;yyyy-MM-dd HH:mm:ss&#39;).alias(&#39;dt&#39;)).collect()
#     [Row(dt=datetime.datetime(1997, 2, 28, 10, 30))]
#
# </div>

# %%
from pyspark.sql.functions import to_timestamp, col
crime_df = df.withColumn('Date',to_timestamp(col('Date'),'MM/dd/yyyy hh:mm:ss a'))
crime_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: integer (nullable = true)
# -- case_number: string (nullable = true)
# -- Date: timestamp (nullable = true)
# -- block: string (nullable = true)
# -- iucr: string (nullable = true)
# -- primary_type: string (nullable = true)
# -- description: string (nullable = true)
# -- location_description: string (nullable = true)
# -- arrest: boolean (nullable = true)
# -- domestic: boolean (nullable = true)
# -- beat: integer (nullable = true)
# -- district: integer (nullable = true)
# -- ward: integer (nullable = true)
# -- community_area: integer (nullable = true)
# -- fbi_code: string (nullable = true)
# -- x_coordinate: integer (nullable = true)
# -- y_coordinate: integer (nullable = true)
# -- year: integer (nullable = true)
# -- updated_on: string (nullable = true)
# -- latitude: double (nullable = true)
# -- longitude: double (nullable = true)
# -- location: string (nullable = true)
# -- historical_wards_2003-2015: integer (nullable = true)
# -- zip_codes: integer (nullable = true)
# -- community_areas: integer (nullable = true)
# -- census_tracts: integer (nullable = true)
# -- wards: integer (nullable = true)
# -- boundaries_-_zip_codes: integer (nullable = true)
# -- police_districts: integer (nullable = true)
# -- police_beats: integer (nullable = true)
#
# </div>

# %%
display(crime_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>case_number</th><th>Date</th><th>block</th><th>iucr</th><th>primary_type</th><th>description</th><th>location_description</th><th>arrest</th><th>domestic</th><th>beat</th><th>district</th><th>ward</th><th>community_area</th><th>fbi_code</th><th>x_coordinate</th><th>y_coordinate</th><th>year</th><th>updated_on</th><th>latitude</th><th>longitude</th><th>location</th><th>historical_wards_2003-2015</th><th>zip_codes</th><th>community_areas</th><th>census_tracts</th><th>wards</th><th>boundaries_-_zip_codes</th><th>police_districts</th><th>police_beats</th></tr></thead><tbody><tr><td>10224738</td><td>HY411648</td><td>2015-09-05T13:30:00.000+0000</td><td>043XX S WOOD ST</td><td>0486</td><td>BATTERY</td><td>DOMESTIC BATTERY SIMPLE</td><td>RESIDENCE</td><td>false</td><td>true</td><td>924</td><td>9</td><td>12</td><td>61</td><td>08B</td><td>1165074</td><td>1875917</td><td>2015</td><td>02/10/2018 03:50:01 PM</td><td>41.815117282</td><td>-87.669999562</td><td>(41.815117282, -87.669999562)</td><td>29</td><td>14924</td><td>59</td><td>706</td><td>3</td><td>37</td><td>23</td><td>108</td></tr><tr><td>10224739</td><td>HY411615</td><td>2015-09-04T11:30:00.000+0000</td><td>008XX N CENTRAL AVE</td><td>0870</td><td>THEFT</td><td>POCKET-PICKING</td><td>CTA BUS</td><td>false</td><td>false</td><td>1511</td><td>15</td><td>29</td><td>25</td><td>06</td><td>1138875</td><td>1904869</td><td>2015</td><td>02/10/2018 03:50:01 PM</td><td>41
td>2020</td><td>9</td><td>17882</td></tr><tr><td>2020</td><td>10</td><td>18372</td></tr><tr><td>2020</td><td>11</td><td>16574</td></tr><tr><td>2020</td><td>12</td><td>16404</td></tr><tr><td>2021</td><td>1</td><td>16001</td></tr><tr><td>2021</td><td>2</td><td>12845</td></tr><tr><td>2021</td><td>3</td><td>15707</td></tr><tr><td>2021</td><td>4</td><td>15266</td></tr><tr><td>2021</td><td>5</td><td>17481</td></tr><tr><td>2021</td><td>6</td><td>18465</td></tr><tr><td>2021</td><td>7</td><td>18890</td></tr><tr><td>2021</td><td>8</td><td>18090</td></tr><tr><td>2021</td><td>9</td><td>18514</td></tr><tr><td>2021</td><td>10</td><td>1945</td></tr></tbody></table></div>

# %% [markdown]
# ###What are the top 10 number of reported crimes by primary type, in descending order of occurence?

# %%
display(crime_df.groupBy('primary_type').count().sort(col('count').desc()).limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>primary_type</th><th>count</th></tr></thead><tbody><tr><td>THEFT</td><td>1560129</td></tr><tr><td>BATTERY</td><td>1360175</td></tr><tr><td>CRIMINAL DAMAGE</td><td>845483</td></tr><tr><td>NARCOTICS</td><td>739334</td></tr><tr><td>ASSAULT</td><td>475340</td></tr><tr><td>OTHER OFFENSE</td><td>461017</td></tr><tr><td>BURGLARY</td><td>412488</td></tr><tr><td>MOTOR VEHICLE THEFT</td><td>341884</td></tr><tr><td>DECEPTIVE PRACTICE</td><td>318391</td></tr><tr><td>ROBBERY</td><td>278295</td></tr></tbody></table></div>

# %% [markdown]
# ### What are the top 5 reported crimes by primary type for each year?

# %%
from pyspark.sql.window import Window

display(crime_df.groupBy(year('date').alias("year"), 'primary_type').count().withColumn("rank", rank().over(Window.partitionBy("year").orderBy(desc("count")))).filter(col("rank")<=5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>primary_type</th><th>count</th><th>rank</th></tr></thead><tbody><tr><td>2001</td><td>THEFT</td><td>99270</td><td>1</td></tr><tr><td>2001</td><td>BATTERY</td><td>93451</td><td>2</td></tr><tr><td>2001</td><td>CRIMINAL DAMAGE</td><td>55854</td><td>3</td></tr><tr><td>2001</td><td>NARCOTICS</td><td>50567</td><td>4</td></tr><tr><td>2001</td><td>ASSAULT</td><td>31384</td><td>5</td></tr><tr><td>2002</td><td>THEFT</td><td>98328</td><td>1</td></tr><tr><td>2002</td><td>BATTERY</td><td>94150</td><td>2</td></tr><tr><td>2002</td><td>CRIMINAL DAMAGE</td><td>55940</td><td>3</td></tr><tr><td>2002</td><td>NARCOTICS</td><td>51789</td><td>4</td></tr><tr><td>2002</td><td>OTHER OFFENSE</td><td>32599</td><td>5</td></tr><tr><td>2003</td><td>THEFT</td><td>98875</td><td>1</td></tr><tr><td>2003</td><td>BATTERY</td><td>88379</td><td>2</td></tr><tr><td>2003</td><td>CRIMINAL DAMAGE</td><td>55011</td><td>3</td></tr><tr><td>2003</td><td>NARCOTICS</td><td>54288</td><td>4</td></tr><tr><td>2003</td><td>OTHER OFFENSE</td><td>31147</td><td>5</td></tr><tr><td>2004</td><td>THEFT</td><td>95463</td><td>1</td></tr><tr><td>2004</td><td>BATTERY</td><td>87136</td><td>2</td></tr><tr><td
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: 0.2684150004443499</div>

# %% [markdown]
# ### find the percentage of reported crimes that results in arrest by year.

# %%
import pandas as pd

crimeByYear=crime_df.groupBy('year').agg(count("year").alias("crime_count")).orderBy("year").toPandas()
arrestByYear=crime_df.filter(col("arrest")=="true").groupBy('year').agg(count("year").alias("arrest_count")).orderBy("year").select("arrest_count").toPandas()

crime=pd.concat([crimeByYear, arrestByYear], axis=1)
crime['arrest_rate']=crime['arrest_count']/crime['crime_count']

display(spark.createDataFrame(crime))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>crime_count</th><th>arrest_count</th><th>arrest_rate</th></tr></thead><tbody><tr><td>2001</td><td>485814</td><td>141923</td><td>0.29213443828296426</td></tr><tr><td>2002</td><td>486775</td><td>141560</td><td>0.2908119767859894</td></tr><tr><td>2003</td><td>475969</td><td>141581</td><td>0.2974584479241295</td></tr><tr><td>2004</td><td>469409</td><td>144694</td><td>0.3082471788994246</td></tr><tr><td>2005</td><td>453755</td><td>140914</td><td>0.3105508479245408</td></tr><tr><td>2006</td><td>448150</td><td>135408</td><td>0.3021488340957269</td></tr><tr><td>2007</td><td>437063</td><td>131870</td><td>0.3017185165525336</td></tr><tr><td>2008</td><td>427132</td><td>110006</td><td>0.2575456767462986</td></tr><tr><td>2009</td><td>392789</td><td>110812</td><td>0.2821158433662857</td></tr><tr><td>2010</td><td>370440</td><td>100521</td><td>0.27135568513119535</td></tr><tr><td>2011</td><td>351918</td><td>96271</td><td>0.2735608863428412</td></tr><tr><td>2012</td><td>336197</td><td>90637</td><td>0.2695949101270981</td></tr><tr><td>2013</td><td>307379</td><td>86515</td><td>0.28146034699833106</td></tr><tr><td>2014</td><td>275654</td><td>79603</td><td>0.28877868632416</td></tr><tr><td>2015</td><td>264581</td><td>70003</td><td>0.2645806010257728</td></tr><tr><td>2016</td><td>269629</td><td>52990</td><td>0.19652930508216845</td></tr><tr><td>2017</td><td>268861</td><td>52589</td><td>0.1955992129762219</td></tr><tr><td>2018</td><td>268465</td><td>53805</td><td>0.20041718659788055</td></tr><tr><td>2019</td><td>260819</td><td>56090</td><td>0.21505335117456933</td></tr><tr><td>2020</td><td>211324</td><td>33859</td><td>0.16022316442997483</td></tr><tr><td>2021</td><td>153204</td><td>18734</td><td>0.12228140257434532</td></tr></tbody></table></div>

# %% [markdown]
# ### What are the top 10 words appearing in the deacription of the crime?

# %%
crime_df.withColumn("word", explode(split("description", " "))).groupBy("word").count().orderBy(desc("count")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-------+
#       word|  count|
# +----------+-------+
#     SIMPLE|1451561|
#         TO|1026849|
#       $500| 987936|
#   DOMESTIC| 623759|
#      UNDER| 622577|
#        AND| 622341|
#    BATTERY| 585457|
#      POSS:| 558787|
#       OVER| 481874|
#    VEHICLE| 459648|
#   PROPERTY| 423157|
#      ENTRY| 406696|
#         OR| 329934|
#      THEFT| 322239|
# AUTOMOBILE| 306857|
#   CANNABIS| 304129|
#      30GMS| 297232|
#   FORCIBLE| 295598|
#       LESS| 290517|
#    HANDGUN| 268389|
# +----------+-------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# #Working with joins

# %%
#The reported crimes dataset has only the district number. Add the district name by joining with the police station dataset.

# load the policy dataset, only keep District and District Name

station_df = spark.read.csv('/mnt/isa460/data/chicago_crime/policestation.csv',header=True, inferSchema=True)
station_df=station_df.select('District', "District Name")
station_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- District: string (nullable = true)
# -- District Name: string (nullable = true)
#
# </div>

# %%
#Join police staion with crime data.
new_df=crime_df.join(station_df, crime_df['district']==station_df['district'], 'inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(new_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>case_number</th><th>Date</th><th>block</th><th>iucr</th><th>primary_type</th><th>description</th><th>location_description</th><th>arrest</th><th>domestic</th><th>beat</th><th>district</th><th>ward</th><th>community_area</th><th>fbi_code</th><th>x_coordinate</th><th>y_coordinate</th><th>year</th><th>updated_on</th><th>latitude</th><th>longitude</th><th>location</th><th>historical_wards_2003-2015</th><th>zip_codes</th><th>community_areas</th><th>census_tracts</th><th>wards</th><th>boundaries_-_zip_codes</th><th>police_districts</th><th>police_beats</th><th>District</th><th>District Name</th></tr></thead><tbody><tr><td>1794153</td><td>G619489</td><td>2001-10-09T07:15:00.000+0000</td><td>025XX N KEDZIE BL</td><td>0460</td><td>BATTERY</td><td>SIMPLE</td><td>RESIDENCE</td><td>false</td><td>true</td><td>1413</td><td>14</td><td>null</td><td>null</td><td>08B</td><td>1154541</td><td>1916874</td><td>2001</td><td>08/17/2015 03:03:40 PM</td><td>41.92772426</td><td>-87.707541179</td><td>(41.92772426, -87.707541179)</td><td>15</td><td>22535</td><td>23</td><td>72</td><td>40</td><td>1</td><td>7</td><td>185</td><td>14</td><td>Shakespeare</td></tr><tr><td>1794154</td><td>G611263</td><td>2001-10-11T17:07:04.000+0000</td><td>008XX N MICHIGAN AV</td><td>0820</td><td>THEFT</td><td>$500 AND UNDER</td><td>DEPARTMENT STORE</td><td>true</td><td>false</td><td>1833</td><td>18</td><td>null</td><td>null</td><td>06</td><td>1177291</td><td>1906083</td><td>2001</td><td>08/17/2015 03:03:40 PM</td><td>41.897627277</td><td>-87.624272204</td><td>(41.897627277, -87.624272204)</td><td>22</td><td>21182</td><td>37</td><td>104</td><td>36</td><td>6</td><td>14</td><td>71</td><td>18</td><td>Near North</td></tr><tr><td>11880934</td><td>JC497319</td><td>2019-10-30T21:00:00.000+0000</td><td>039XX W WASHINGTON BLVD</td><td>1330</td><td>CRIMINAL TRESPASS</td><td>TO LAND</td><td>CHA APARTMENT</td><td>false</td><td>false</td><td>1122</td><td>11</td><td>28</td><td>26</td><td>26</td><td>1150156</td><td>1900128</td><td>2019</td><td>11/06/2019 03:59:02 PM</td><td>41.881858277</td><td>-87.724091496</td><td>(41.881858277, -87.724091496)</td><td>11</td><td>21572</td><td>27</td><td>658</td><td>23</td><td>30</td><td>16</td><td>82</td><td>11</td><td>Harrison</td></tr><tr><td>1771539</td><td>G585382</td><td>2001-09-30T00:45:00.000+0000</td><td>017XX N KEYSTONE AV</td><td>1310</td><td>CRIMINAL DAMAGE</td><td>TO PROPERTY</td><td>RESIDENCE</td><td>false</td><td>false</td><td>2534</td><td>25</td><td>null</td><td>null</td><td>14</td><td>1149151</td><td>1911306</td><td>2001</td><td>08/17/2015 03:03:40 PM</td><td>41.91255139</td><td>-87.727492025</td><td>(41.91255139, -87.727492025)</td><td>27</td><td>22615</td><td>24</td><td>285</td><td>49</td><td>2</td><td>6</td><td>194</td><td>25</td><td>Grand Central</td></tr><tr><td>1794155</td><td>G615403</td><td>2001-10-13T13:02:00.000+0000</td><td>048XX N CLARK ST</td><td>0460</td><td>BATTERY</td><td>SIMPLE</td><td>PARKING LOT/GARAGE(NON.RESID.)</td><td>false</td><td>false</td><td>2032</td><td>20</td><td>null</td><td>null</td><td>08B</td><td>1165200</td><td>1932827</td><td>2001</td><td>08/17/2015 03:03:40 PM</td><td>41.971279895</td><td>-87.667918415</td><td>(41.971279895, -87.667918415)</td><td>37</td><td>22616</td><td>31</td><td>610</td><td>18</td><td>15</td><td>2</td><td>59</td><td>20</td><td>Lincoln</td></tr><tr><td>1794156</td><td>G619488</td><td>2001-10-11T14:30:00.000+0000</td><td>019XX E 71 ST</td><td>2826</td><td>OTHER OFFENSE</td><td>HARASSMENT BY ELECTRONIC MEANS</td><td>COMMERCIAL / BUSINESS OFFICE</td><td>false</td><td>false</td><td>332</td><td>3</td><td>null</td><td>null</td><td>26</td><td>1190663</td><td>1858356</td><td>2001</td><td>08/17/2015 03:03:40 PM</td><td>41.766348301</td><td>-87.576703336</td><td>(41.766348301, -87.576703336)</td><td>32</td><td>22538</td><td>39</td><td>381</td><td>33</td><td>24</td><td>1 ...

# %% [markdown]
# ### Which district has the highest arrest rate?

# %%
from pyspark.sql.functions import *
new_df.filter(col('Arrest')=='true').groupBy('District Name').count().sort(col('count').desc()).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+------+
#  District Name| count|
# +--------------+------+
#       Harrison|204240|
#         Austin|128805|
#      Englewood|123624|
#  Grand Central|117196|
#   Chicago Lawn|115871|
#        Gresham|114607|
#        Deering|103421|
#          Ogden|102849|
# Grand Crossing| 98629|
#  South Chicago| 96912|
#      Wentworth| 94498|
#      Near West| 86179|
#        Calumet| 84927|
#        Central| 82515|
#     Near North| 79101|
#      Town Hall| 71921|
#    Shakespeare| 60060|
#    Morgan Park| 52114|
#    Rogers Park| 50410|
# Jefferson Park| 46729|
# +--------------+------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# Create widget based on primary type

# %%
dbutils.widgets.removeAll()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_df.createOrReplaceTempView('crime')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
primary_type = spark.sql("select distinct primary_type from crime").rdd.map(lambda row : row[0]).collect()
primary_type.sort()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.widgets.dropdown("Type", "THEFT", [str(x) for x in primary_type])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Find the day of the week with the most reported crime by certain primary type

# %%
display(crime_df.filter(col('primary_type')==getArgument("Type")).groupBy(date_format('date','E').alias('week day')).count().orderBy('count', ascending=False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>week day</th><th>count</th></tr></thead><tbody><tr><td>Fri</td><td>41410</td></tr><tr><td>Sat</td><td>41293</td></tr><tr><td>Mon</td><td>39842</td></tr><tr><td>Sun</td><td>39531</td></tr><tr><td>Tue</td><td>38972</td></tr><tr><td>Wed</td><td>38814</td></tr><tr><td>Thu</td><td>38433</td></tr></tbody></table></div>
